# %%
import pandas as pd
import numpy as np

# %%
seating_data = pd.read_csv('C:/Users/tmanett/Maple Leaf Sports & Entertainment Ltd/Team - SEA - Strategy, Esports & Analytics - Documents/Analytics Team/Manifest/TML_Manifest_Cleaned_Data_May23.csv')
coordinates = pd.read_csv("C:/Users/tmanett/Desktop/Manifest Optimization/Leafs_Seat_Coordinates_1.csv")
# Out:
# C:\Users\tmanett\AppData\Local\Temp\ipykernel_29880\219998706.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   seating_data = pd.read_csv('C:/Users/tmanett/Maple Leaf Sports & Entertainment Ltd/Team - SEA - Strategy, Esports & Analytics - Documents/Analytics Team/Manifest/TML_Manifest_Cleaned_Data_May23.csv')

# %%
seating_data.info()
seating_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303982 entries, 0 to 303981
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               303982 non-null  int64
#  1   event_date               303982 non-null  object
#  2   event_name               303982 non-null  object
#  3   section_name             303982 non-null  object
#  4   row_name                 303982 non-null  object
#  5   seat_num                 303982 non-null  int64
#  6   activity_name            303982 non-null  object
#  7   fiscal                   303982 non-null  object
#  8   tier                     303982 non-null  int64
#  9   def_price_code           303982 non-null  object
#  10  quality                  303982 non-null  int64
#  11  direction                303982 non-null  object
#  12  bowl_level               303982 non-null  object
# ...

# %%
coordinates.info()
coordinates.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20594 entries, 0 to 20593
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Section        20594 non-null  object
#  1   Row            20594 non-null  object
#  2   Seat           20594 non-null  int64
#  3   Seat Center X  19748 non-null  float64
#  4   Seat Center Y  19748 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 804.6+ KB
#   Section Row  Seat  Seat Center X  Seat Center Y
# 0   ES200  R1     1         3714.0         1682.0
# 1   ES200  R1     2         3722.0         1673.0
# 2   ES200  R1     3         3730.0         1664.0
# 3   ES200  R1     4         3738.0         1655.0
# 4   ES200  R1     5         3746.0         1646.0
